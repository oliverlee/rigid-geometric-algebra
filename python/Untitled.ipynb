# %%
import pyvista as pv
from pyvista.trame import launch_server

# %%
print(pv.Report())
# Out:
# --------------------------------------------------------------------------------
#   Date: Tue Sep 17 15:01:23 2024 PDT
#
#                   OS : Darwin (macOS 14.6.1)
#               CPU(s) : 8
#              Machine : arm64
#         Architecture : 64bit
#                  RAM : 8.0 GiB
#          Environment : Jupyter
#          File system : apfs
#           GPU Vendor : Apple
#         GPU Renderer : Apple M1
#          GPU Version : 4.1 Metal - 88.1
#     MathText Support : True
#
#   Python 3.12.4 (main, Jul 25 2024, 22:11:22) [Clang 18.1.8 ]
#
#              pyvista : 0.44.1
#                  vtk : 9.3.1
#                numpy : 2.1.1
#           matplotlib : 3.9.2
#               scooby : 0.10.0
#                pooch : 1.8.2
#               pillow : 10.4.0
#              imageio : 2.35.1
#              IPython : 8.27.0
#             colorcet : 3.1.0
#              cmocean : 4.0.3
#           ipywidgets : 8.1.5
#               meshio : 5.3.5
#           jupyterlab : 4.2.5
#                trame : 3.6.5
#         trame_client : 3.2.5
#         trame_server : 3.1.2
#            trame_vtk : 2.8.10
#        trame_vuetify : 2.7.1
# jupyter_server_proxy : 4.4.0
#         nest_asyncio : 1.6.0
# --------------------------------------------------------------------------------

# %%
server = launch_server()

# %%
server.running
# Out:
# True

# %%
import numpy as np

import pyvista as pv
#pv.global_theme.trame.server_proxy_enabled = True
#pv.global_theme.trame.jupyter_extension_enabled = True
pv.set_jupyter_backend('trame') 

rng = np.random.default_rng(seed=0)
points = rng.random((1000, 3))

rgba = points - points.min(axis=0)
rgba /= rgba.max(axis=0)
pv.plot(
    points,
    scalars=rgba,
    render_points_as_spheres=True,
    point_size=20,
    rgba=True,
)
# Out:
# Widget(value='<iframe src="/proxy/52485/index.html?ui=P_0x11b2207d0_0&reconnect=auto" class="pyvista" style="w…

# %%
# %matplotlib notebook

from matplotlib import pyplot as plt 

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(*np.unstack(points, axis=1))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.75">
